# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path
import datetime as dt
# %matplotlib inline

# %%
IRS_2015_data = pd.read_csv(
    Path("IRS_income_tax_data/2015_IRS_income_tax_data.csv"))
IRS_2016_data = pd.read_csv(
    Path("IRS_income_tax_data/2016_IRS_income_tax_data.csv"))
IRS_2017_data = pd.read_csv(
    Path("IRS_income_tax_data/2017_IRS_income_tax_data.csv"))
IRS_2018_data = pd.read_csv(
    Path("IRS_income_tax_data/2018_IRS_income_tax_data.csv"))
IRS_2019_data = pd.read_csv(
    Path("IRS_income_tax_data/2019_IRS_income_tax_data.csv"))

# %%
IRS_2015_data = pd.read_csv(
    Path("IRS_income_tax_data/2015_IRS_income_tax_data.csv"))

IRS_2015_data.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  836320.0  481570.0  109790.0  233260.0
# 1          1    AL        0         2  494830.0  206630.0  146250.0  129390.0
# 2          1    AL        0         3  261250.0   80720.0  139280.0   36130.0
# 3          1    AL        0         4  166690.0   28510.0  124650.0   10630.0
# 4          1    AL        0         5  212660.0   19520.0  184320.0    4830.0
#
#        PREP         N2  ...    N10300     A10300  N85530  A85530  N85300  \
# 0  455560.0  1356760.0  ...  373410.0   328469.0     0.0     0.0     0.0
# 1  275920.0  1010990.0  ...  395880.0   965011.0     0.0     0.0     0.0
# 2  155100.0   583910.0  ...  251490.0  1333418.0     0.0     0.0     0.0
# 3   99950.0   423990.0  ...  165320.0  1414283.0     0.0     0.0     0.0
# 4  126860.0   589490.0  ...  212000.0  3820152.0   420.0   168.0    60.0
#
#    A85300   N11901    A11901    N11902     A11902
# ...

# %%
IRS_2015_data_sliced = IRS_2015_data[["STATE","zipcode","A18425"]]

IRS_2015_data_sliced.head()
# Out:
#   STATE  zipcode    A18425
# 0    AL        0   19401.0
# 1    AL        0  127062.0
# 2    AL        0  206067.0
# 3    AL        0  239703.0
# 4    AL        0  738470.0

# %%
IRS_2015_data_sliced.to_csv("IRS_sliced_data_2015.csv", index = False)

# %%
IRS_2016_data = pd.read_csv(
    Path("IRS_income_tax_data/2016_IRS_income_tax_data.csv"))

IRS_2016_data.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1   mars1   MARS2   MARS4    PREP  \
# 0          1    AL        0         1  815440  477700  105350  221200  440830
# 1          1    AL        0         2  495830  211930  142340  128890  272440
# 2          1    AL        0         3  263390   83420  137870   36340  154880
# 3          1    AL        0         4  167190   29420  124060   10610   99700
# 4          1    AL        0         5  217440   20240  188080    4880  129410
#
#         N2  ...  N10300   A10300  N85530  A85530  N85300  A85300  N11901  \
# 0  1296920  ...  367320   330066       0       0       0       0   63420
# 1   996240  ...  398050   984297       0       0       0       0   74090
# 2   584000  ...  253180  1349246       0       0       0       0   64000
# 3   421720  ...  165830  1425430       0       0       0       0   45020
# 4   601040  ...  216720  3922449     390     155      60      19   82940
#
#    A11901  N11902   A11902
# 0   51444  711580  1831661
# ...

# %%
IRS_2016_data_sliced = IRS_2016_data[["STATE","zipcode","A18425"]]

IRS_2016_data_sliced.head()
# Out:
#   STATE  zipcode  A18425
# 0    AL        0   19585
# 1    AL        0  127434
# 2    AL        0  208782
# 3    AL        0  237633
# 4    AL        0  760514

# %%
IRS_2016_data_sliced.to_csv("IRS_sliced_data_2016.csv", index = False)

# %%
IRS_2017_data = pd.read_csv(
    Path("IRS_income_tax_data/2017_IRS_income_tax_data.csv"))

IRS_2017_data.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  802640.0  474470.0   99850.0  216600.0
# 1          1    AL        0         2  499070.0  218590.0  137460.0  129760.0
# 2          1    AL        0         3  268590.0   89780.0  134440.0   38280.0
# 3          1    AL        0         4  170880.0   32180.0  124070.0   11660.0
# 4          1    AL        0         5  229870.0   22810.0  196990.0    5540.0
#
#         ELF    CPREP  ...  N85300  A85300   N11901    A11901    N11900  \
# 0  717050.0  44090.0  ...     0.0     0.0  64680.0   53602.0  700940.0
# 1  448190.0  26230.0  ...     0.0     0.0  77660.0  118725.0  419640.0
# 2  241060.0  14160.0  ...     0.0     0.0  67820.0  156752.0  201030.0
# 3  154120.0   7980.0  ...     0.0     0.0  48440.0  141721.0  121930.0
# 4  208380.0  11120.0  ...    50.0    19.0  91100.0  465160.0  138250.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %%
IRS_2017_data_sliced = IRS_2017_data[["STATE","zipcode","A18425"]]

IRS_2017_data_sliced.head()
# Out:
#   STATE  zipcode    A18425
# 0    AL        0   19005.0
# 1    AL        0  126196.0
# 2    AL        0  211728.0
# 3    AL        0  233024.0
# 4    AL        0  788622.0

# %%
IRS_2017_data_sliced.to_csv("IRS_sliced_data_2017.csv", index = False)

# %%
IRS_2018_data = pd.read_csv(
    Path("IRS_income_tax_data/2018_IRS_income_tax_data.csv"))

IRS_2018_data.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  768120.0  466830.0   90960.0  198750.0
# 1          1    AL        0         2  503430.0  225110.0  130060.0  134320.0
# 2          1    AL        0         3  274590.0   95560.0  131770.0   41020.0
# 3          1    AL        0         4  174830.0   35560.0  123370.0   12700.0
# 4          1    AL        0         5  245150.0   25990.0  207950.0    6480.0
#
#         ELF    CPREP  ...  N85300  A85300   N11901    A11901    N11900  \
# 0  696930.0  37470.0  ...     0.0     0.0  59030.0   50007.0  669420.0
# 1  457510.0  23180.0  ...     0.0     0.0  77300.0  111047.0  424280.0
# 2  248630.0  13210.0  ...     0.0     0.0  68920.0  148870.0  205830.0
# 3  159190.0   6830.0  ...     0.0     0.0  47730.0  136776.0  126560.0
# 4  224280.0  10500.0  ...    50.0    58.0  98980.0  446992.0  145780.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %%
IRS_2018_data_sliced = IRS_2018_data[["STATE","zipcode","A18425"]]

IRS_2018_data_sliced.head()
# Out:
#   STATE  zipcode    A18425
# 0    AL        0    2905.0
# 1    AL        0   27454.0
# 2    AL        0   56235.0
# 3    AL        0   60309.0
# 4    AL        0  292798.0

# %%
IRS_2018_data_sliced.to_csv("IRS_sliced_data_2018.csv", index = False)

# %%
IRS_2019_data = pd.read_csv(
    Path("IRS_income_tax_data/2019_IRS_income_tax_data.csv"))

IRS_2019_data.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL        0         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL        0         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL        0         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL        0         5  257010.0   28180.0  216740.0    7150.0
#
#         ELF    CPREP  ...  N85300  A85300    N11901    A11901    N11900  \
# 0  712890.0  30670.0  ...     0.0     0.0   62720.0   51936.0  671860.0
# 1  481760.0  18960.0  ...     0.0     0.0   85860.0  122569.0  438020.0
# 2  260570.0  10670.0  ...     0.0     0.0   73980.0  154932.0  212040.0
# 3  164300.0   5020.0  ...     0.0     0.0   51330.0  139065.0  126850.0
# 4  236850.0   8400.0  ...    90.0   141.0  104290.0  460071.0  152790.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %%
IRS_2019_data_sliced = IRS_2019_data[["STATE","zipcode","A18425"]]

IRS_2019_data_sliced.head()
# Out:
#   STATE  zipcode    A18425
# 0    AL        0    2661.0
# 1    AL        0   22962.0
# 2    AL        0   54996.0
# 3    AL        0   56947.0
# 4    AL        0  292110.0

# %%
IRS_2019_data_sliced.to_csv("IRS_sliced_data_2019.csv", index = False)

# %%
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['IRS_sliced_data_2015.csv',
#  'IRS_sliced_data_2016.csv',
#  'IRS_sliced_data_2017.csv',
#  'IRS_sliced_data_2018.csv',
#  'IRS_sliced_data_2019.csv']

# %%
IRS_sliced_data = pd.DataFrame()

for file in csv_files:
            df_temp = pd.read_csv(file)
            IRS_sliced_data = df_append.append(df_temp, ignore_index=True)
            
IRS_sliced_data.head()
# Out:
# C:\Users\Maria Angels Bonany\AppData\Local\Temp\ipykernel_7796\4232743295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   IRS_sliced_data = df_append.append(df_temp, ignore_index=True)
# C:\Users\Maria Angels Bonany\AppData\Local\Temp\ipykernel_7796\4232743295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   IRS_sliced_data = df_append.append(df_temp, ignore_index=True)
# C:\Users\Maria Angels Bonany\AppData\Local\Temp\ipykernel_7796\4232743295.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   IRS_sliced_data = df_append.append(df_temp, ignore_index=True)
# ...

# %%
# creating a new file

IRS_sliced_data.to_csv("IRS_sliced_data_2015_2019.csv", index = False)
